# %% [markdown]
# # Using Genestack Omics APIs for differential expression analysis

# %% [markdown]
# ### 1. Connect to the instance

# %%
import os, time
import pandas as pd
import matplotlib.pyplot as plt
import integration_curator # Genestack client library

os.environ['PRED_SPOT_HOST'] = 'occam.genestack.com'
os.environ['PRED_SPOT_TOKEN'] = '<your token>'
os.environ['PRED_SPOT_VERSION'] = 'default-released'

omics_api = integration_curator.OmicsQueriesApi()

# %% [markdown]
# ### 2. Get samples

# %%
study_filter = 'genestack:accession=GSF962829'
sample_filter = ' OR '.join(['"GTEX original SMTS"="%s"' % x 
                             for x in ['Prostate', 'Breast', 'Salivary Gland']])

start = time.time()
data = omics_api.search_samples(
    study_filter=study_filter, 
    sample_filter=sample_filter
)
samples = pd.DataFrame.from_dict([item['metadata'] for item in data.data])
print('Time to get %s samples: %i seconds\n' % (samples.shape[0], time.time()-start))

samples.head()
# Out:
# Time to get 569 samples: 1 seconds
#   genestack:accession          Sample Source ID               Sample Name  \
# 0           GSF968643  GTEX-15UF6-0126-SM-6PAMB  GTEX-15UF6-0126-SM-6PAMB
# 1           GSF972740   GTEX-RWSA-2026-SM-47JX8   GTEX-RWSA-2026-SM-47JX8
# 2           GSF974788   GTEX-XOT4-0726-SM-4GIAW   GTEX-XOT4-0726-SM-4GIAW
# 3           GSF974781   GTEX-XMK1-2626-SM-4B65R   GTEX-XMK1-2626-SM-4B65R
# 4           GSF975793   GTEX-ZDXO-0126-SM-5S2ND   GTEX-ZDXO-0126-SM-5S2ND
#
#        Organism  Disease                Tissue Cell Type Cell Line  \
# 0  Homo sapiens  Healthy                breast      None      None
# 1  Homo sapiens  Healthy        prostate gland      None      None
# 2  Homo sapiens  Healthy                breast      None      None
# 3  Homo sapiens  Healthy  minor salivary gland      None      None
# 4  Homo sapiens  Healthy                breast      None      None
#
#                 Sampling Site   Age  ... Specimen Collection Time Unit  \
# 0                Right Breast  None  ...                         hours
# 1                    Prostate  None  ...                         hours
# 2                Right Breast  None  ...                         hours
# 3  Inner surface of lower lip  None  ...                         hours
# 4                Right Breast  None  ...                         hours
#
#              Harvest Location  \
# 0                Right Breast
# 1                    Prostate
# 2                Right Breast
# 3  Inner surface of lower lip
# 4                Right Breast
#
#                                        Specimen Type   Tissue or Cell Type  \
# 0  DNA or RNA Extraction from Paxgene-derived Lys...        Mammary Tissue
# 1                 RNA isolation_PAXgene Tissue miRNA              Prostate
# 2                 RNA isolation_PAXgene Tissue miRNA        Mammary Tissue
# 3                 RNA isolation_PAXgene Tissue miRNA  Minor Salivary Gland
# 4  RNA Extraction from Paxgene-derived Lysate Pla...        Mammary Tissue
#
#   Donor Disease             Sample Source Donor Treatment - Treatment Name  \
# 0       Healthy  GTEX-15UF6-0126-SM-6PAMB                          Unknown
# 1       Healthy   GTEX-RWSA-2026-SM-47JX8                          Unknown
# 2       Healthy   GTEX-XOT4-0726-SM-4GIAW                          Unknown
# 3       Healthy   GTEX-XMK1-2626-SM-4B65R                          Unknown
# 4       Healthy   GTEX-ZDXO-0126-SM-5S2ND                          Unknown
#
#   Sample Type GTEX original SMTS Specimen Treatment - Treatment Name
# 0         RNA             Breast                           Untreated
# 1         RNA           Prostate                           Untreated
# 2         RNA             Breast                           Untreated
# 3         RNA     Salivary Gland                           Untreated
# 4         RNA             Breast                           Untreated
#
# [5 rows x 38 columns]

# %% [markdown]
# ### 3. Get expression data

# %%
gene = 'ENSG00000014257'
ex_query = 'Gene=%s MinValue=0.0' % gene

start = time.time()
data = omics_api.search_expression_data(
    study_filter=study_filter,
    sample_filter=sample_filter,
    ex_query=ex_query
)
expressions = pd.DataFrame.from_dict({'genestack:accession': item['relationships']['sample'], 
                                      'expression': item['expression']} for item in data.data)
print('Time to get %s expression values: %i seconds\n' % (expressions.shape[0], time.time()-start))

expressions.head()
# Out:
# Time to get 539 expression values: 0 seconds
#   genestack:accession  expression
# 0           GSF962841        71.0
# 1           GSF962843       399.0
# 2           GSF962860     92804.0
# 3           GSF962879    273103.0
# 4           GSF962881      1038.0

# %% [markdown]
# ### 4. Differential expression plot

# %%
samples_expressions = pd.merge(samples, expressions)
samples_expressions.boxplot('expression', 'Tissue', rot=0, figsize=(10,5))
plt.title('Expression of %s' % gene)
x = plt.suptitle('')
